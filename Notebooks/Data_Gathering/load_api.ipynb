# %%
import requests
import pandas as pd

# %%
access_token="eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5YzU3ODdkNzI5MTU1NDk2NDk3ZmZiMTRkZTQzOWU3OCIsIm5iZiI6MTc1NTU5MTQ5Ny4wNTksInN1YiI6IjY4YTQzMzQ5YmI0NTI4MTk2ODU2N2UwYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.rzU8LBK-fWbJANYswj3-J30xqd-rVvnA0OlDHjotVas"

url=f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"
headers = {
            "accept": "application/json",
            "Authorization": f"Bearer {access_token}"
        }
response = requests.get(url, headers=headers, timeout=10)

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/v8xVDqt8uCul3c3mgx4VpGCwxJC.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 36.0606,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.712,
#    'vote_count': 29085},
#   {'adult': False,
#    'backdrop_path': '/jdHsptJbtalEuVhCV5i7kSC3g0x.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/v8xVDqt8uCul3c3mgx4VpGCwxJC.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 36.0606,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.712,
#   'vote_count': 29085},
#  {'adult': False,
#   'backdrop_path': '/jdHsptJbtalEuVhCV5i7kSC3g0x.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results']).head()[['id','original_title','overview','release_date','original_language','popularity','vote_count','vote_average']]
# Out:
#     id            original_title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2  In the continuing saga of the Corleone crime f...   1974-12-20
# 3  The true story of how businessman Oskar Schind...   1993-12-15
# 4  The defense and the prosecution have rested an...   1957-04-10
#
#   original_language  popularity  vote_count  vote_average
# 0                en     36.0606       29085         8.712
# 1                en     35.0280       21972         8.685
# 2                en     21.0770       13277         8.571
# 3                en     17.7591       16798         8.566
# 4                en     13.4176        9475         8.500

# %%
df=pd.DataFrame()

# %%
import requests
import pandas as pd
import time

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5YzU3ODdkNzI5MTU1NDk2NDk3ZmZiMTRkZTQzOWU3OCIsInN1YiI6IjY4YTQzMzQ5YmI0NTI4MTk2ODU2N2UwYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.rzU8LBK-fWbJANYswj3-J30xqd-rVvnA0OlDHjotVas"
}

df = pd.DataFrame()  # initialize empty DataFrame

for i in range(1, 429):
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
    response = requests.get(url, headers=headers)
    
    temp_df = pd.DataFrame(response.json()['results'])[
        ['id','original_title','overview','release_date','original_language','popularity','vote_count','vote_average']
    ]
    
    df = df.append(temp_df, ignore_index=True)  # assign back to df
    time.sleep(0.2)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %%
access_token="eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5YzU3ODdkNzI5MTU1NDk2NDk3ZmZiMTRkZTQzOWU3OCIsIm5iZiI6MTc1NTU5MTQ5Ny4wNTksInN1YiI6IjY4YTQzMzQ5YmI0NTI4MTk2ODU2N2UwYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.rzU8LBK-fWbJANYswj3-J30xqd-rVvnA0OlDHjotVas"

url=f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"
headers = {
            "accept": "application/json",
            "Authorization": f"Bearer {access_token}"
        }

# %%
import requests
import time
import requests
import pandas as pd
import time

session = requests.Session()
session.headers.update(headers)

df_list = []
columns = ['id','original_title','overview','release_date','original_language','popularity','vote_count','vote_average']

for i in range(1, 429):
    for attempt in range(5):
        try:
            url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
            response = session.get(url, timeout=10)
            response.raise_for_status()
            temp_df = pd.DataFrame(response.json()['results'])[columns]
            df_list.append(temp_df)
            time.sleep(0.8)  # delay after successful request
            break
        except requests.exceptions.RequestException as e:
            wait = 2 ** attempt  # exponential backoff
            print(f"Page {i} failed on attempt {attempt+1}: {e}. Retrying in {wait}s...")
            time.sleep(wait)

# %%
df=pd.concat(df_list,ignore_index=True)

# %%
df.shape
# Out:
# (8560, 8)

# %%
df.to_csv('csv_file/movies.csv')
